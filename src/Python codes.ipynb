# %%
    # Parser Function  in a directed research for text on the above codes: 
    def get_parse(): 
        # Console orders: 
            # sudo pip install requests --upgrade
            # sudo pip install beautifulsoup4 --upgrade
        # Packages required:
        import requests
        from bs4 import BeautifulSoup
        # URL website page to be parsed:
        url = "https://www.meneame.net"
        # requests.get() method for getting the data:
        r = requests.get(url)
        # BeautifulSoup parser revises the content:
        soup = BeautifulSoup(r.content)
        # b objects from the html page are our interest:
        links = soup.find_all("div", {"class": "news-summary"})
        # Text from b objects are listed:
        for link in links:
            h = link.text
            # "news-summary" text objects:
            print(link.text)
        return 
    # Displaying get_parse() function title webpage ouputs for a test:
    get_parse()
# Out:
#     101 meneos   menéalo    779 clics        El exdueño de Pocoyó monta un bufete de abogados dedicado a querellarse contra jueces      por raboto  a vozpopuli.com     ____  publicado:  ____  José María Castillejo impulsa, de la mano de dos socios, Dédalo Legal, un bufete que lucha contra la corrupción en todas sus formas, incluida, resalta, la judicial     44  57  1  K   303     actualidad     21 comentarios  compartir    Compartir en Facebook   Compartir en Twitter   Compartir por Correo   Copiar enlace       44  57  1  K   303     actualidad
# ...
